# %%
plot(cos(x)**2, xmin = 0, xmax = pi/2) + plot(cos(x + pi/6)**2, xmin = 0, xmax = pi/2, color = 'red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(cos(x)**2, xmin = 0, xmax = pi/2) + plot(cos(x - pi/6)**2, xmin = 0, xmax = pi/2, color = 'red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sin(x)**2, xmin = 0, xmax = pi/2) + plot(sin(x + pi/6)**2, xmin = 0, xmax = pi/2, color = 'red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(sin(x)**2, xmin = 0, xmax = pi/2) + plot(sin(x - pi/6)**2, xmin = 0, xmax = pi/2, color = 'red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
n(find_root(cos(x)**2 == cos(x + pi/6)**2, 0, pi/2)/pi)
# Out:
# 0.416666666666782

# %%
f(x) = 0.5*(cos(x/2)^2 + sin(x/2 + pi/6)^2)
show(g)
# Out:
# x |--> 0.500000000000000*cos(1/2*x)^2 + 0.500000000000000*sin(-1/6*pi + 1/2*x)^2

# %%
plot(f(x), xmin = 0, xmax = pi) + plot(g(x), xmin = 0, xmax = pi, color = 'red') + plot(1 - f(x), xmin = 0, xmax = pi, color = 'hotpink') + plot(1 - g(x), xmin = 0, xmax = pi, color = 'green')
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
n(find_local_maximum(f(x), 0, pi)[1]/pi)
# Out:
# 0.333333326880417

# %%
n(find_local_maximum(1 - g(x), 0, pi)[1]/pi)
# Out:
# 0.666666666605124

# %%
var('a')
P(x) = p*cos(x/2)**2 + (1-p)*sin((x - a)/2)**2
Q(x) = 1 - P(x)

# %%
g = plot(P.subs(a == 0), xmin = 0, xmax = pi, color = 'blue') \
+ plot(Q.subs(a == 0), xmin = 0, xmax = pi, color = 'red') 
for n in range(1,10):
    g += plot(P.subs(a == pi/n), xmin = 0, xmax = pi, color = 'blue') \
    + plot(Q.subs(a == pi/n), xmin = 0, xmax = pi, color = 'red')
show(g)
# Out:
# Graphics object consisting of 20 graphics primitives
