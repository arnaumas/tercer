# %%
var('x y')
grafics = [implicit_plot(2*y^2 - 2*x^2 - y^4 - k/100 , xrange = (-1.5,1.5), yrange = (-1.5, 1.5), color = 'blue') for k in range(-300, 150, 25)]

# %%
fletxes1 = [arrow((sqrt(-k/200),0.01), (sqrt(-k/200),-0.01), arrowsize = 2) + arrow((-sqrt(-k/200),-0.01), (-sqrt(-k/200),0.01), arrowsize = 2) for k in range(-300, 0, 25)]

# %%
fletxes2 = [arrow((0.05,0.05), (0.04, 0.04), arrowsize = 2), arrow((-0.05,-0.05), (-0.04,-0.04), arrowsize = 2), arrow((0.07, -0.07), (0.08,-0.08), arrowsize = 2), arrow((-0.07, 0.07), (-0.08,0.08), arrowsize = 2)]

# %%
critics = point((0,0)) + point((0,1)) + point((0,-1))

# %%
fletxes3 = [arrow((sqrt((1 - k/100)/2),1.01), (sqrt((1 - k/100)/2),0.99), arrowsize = 2) + arrow((-sqrt((1 - k/100)/2),0.99), (-sqrt((1 - k/100)/2),1.01), arrowsize = 2) for k in range(-300, 100, 25)]

# %%
fletxes4 = [arrow((-sqrt((1 - k/100)/2),-1.01), (-sqrt((1 - k/100)/2),-0.99), arrowsize = 2) + arrow((sqrt((1 - k/100)/2),-0.99), (sqrt((1 - k/100)/2),-1.01), arrowsize = 2) for k in range(-300, 100, 25)]

# %%
fig = sum(grafics) + critics + sum(fletxes1) + sum(fletxes2) + sum(fletxes3) + sum(fletxes4)

# %%
fig.save('retrat-hamiltonia.png')

# %%
plot(cos(x)^2 - sin(x)^2, xmin = 0, xmax = 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive
