# %% [markdown]
# # Llei de Malus
#
# Llei teòrica $I(\theta)=\frac{1}{2}\text{cos}^2(\theta)$

# %% [markdown]
# Intensitat en funció de l'angle de desviació.
#
# * `I` intensitat mesurada per cada angle
# * `Theta[i]` angle de gir del polaritzador

# %% [markdown]
# Angles: º
# Intensitat: mW
# Pecisió angles: 2º
# Precisió intensitat: 0.01 mW

# %%
Int=[]
Theta=[]

# %%
Int=[0,0.06,0.15,0.30,0.46,0.65,0.79,0.91,0.99,0.95,0.93,0.97,0.98,1.00,1.00,1.01,1.01,1.00,1.00,0.99,0.98,0.97,0.96,0.94,0.92,0.90,0.88,0.86,0.72,0.56,0.38,0.21,0.09,0.02,0]
Theta=[80,90,100,110,120,130,140,150,160,154,152,156,158,162,164,166,168,170,172,174,176,178,180,182,184,186,188,190,200,210,220,230,240,250,260]

# %%
len(Theta)
# Out:
# 35

# %% [markdown]
# `Parells` és la llista dels punts a representar.

# %%
Parells=[]
a=len(Int)
for k in range(len(Int)):
    Parells.append((cos((Theta[k]+13)*pi/180)^2,Int[k]))
Parells
# Out:
# [(cos(29/60*pi)^2, 0),
#  (cos(77/180*pi)^2, 0.0600000000000000),
#  (cos(67/180*pi)^2, 0.150000000000000),
#  (cos(19/60*pi)^2, 0.300000000000000),
#  (cos(47/180*pi)^2, 0.460000000000000),
#  (cos(37/180*pi)^2, 0.650000000000000),
#  (cos(3/20*pi)^2, 0.790000000000000),
#  (cos(17/180*pi)^2, 0.910000000000000),
#  (cos(7/180*pi)^2, 0.990000000000000),
#  (cos(13/180*pi)^2, 0.950000000000000),
#  (1/16*(sqrt(6) + sqrt(2))^2, 0.930000000000000),
#  (cos(11/180*pi)^2, 0.970000000000000),
#  (cos(1/20*pi)^2, 0.980000000000000),
#  (cos(1/36*pi)^2, 1.00000000000000),
#  (cos(1/60*pi)^2, 1.00000000000000),
#  (cos(1/180*pi)^2, 1.01000000000000),
#  (cos(1/180*pi)^2, 1.01000000000000),
#  (cos(1/60*pi)^2, 1.00000000000000),
#  (cos(1/36*pi)^2, 1.00000000000000),
#  (cos(7/180*pi)^2, 0.990000000000000),
#  (cos(1/20*pi)^2, 0.980000000000000),
#  (cos(11/180*pi)^2, 0.970000000000000),
#  (cos(13/180*pi)^2, 0.960000000000000),
#  (1/16*(sqrt(6) + sqrt(2))^2, 0.940000000000000),
#  (cos(17/180*pi)^2, 0.920000000000000),
#  (cos(19/180*pi)^2, 0.900000000000000),
#  (cos(7/60*pi)^2, 0.880000000000000),
#  (cos(23/180*pi)^2, 0.860000000000000),
#  (cos(11/60*pi)^2, 0.720000000000000),
#  (cos(43/180*pi)^2, 0.560000000000000),
#  (cos(53/180*pi)^2, 0.380000000000000),
#  (cos(7/20*pi)^2, 0.210000000000000),
#  (cos(73/180*pi)^2, 0.0900000000000000),
#  (cos(83/180*pi)^2, 0.0200000000000000),
#  (cos(29/60*pi)^2, 0)]

# %%
point(Parells)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
Parells2=[]
a=len(Int)
for k in range(len(Int)):
    Parells2.append(((Theta[k]),Int[k]))
Parells2
# Out:
# [(80, 0),
#  (90, 0.0600000000000000),
#  (100, 0.150000000000000),
#  (110, 0.300000000000000),
#  (120, 0.460000000000000),
#  (130, 0.650000000000000),
#  (140, 0.790000000000000),
#  (150, 0.910000000000000),
#  (160, 0.990000000000000),
#  (154, 0.950000000000000),
#  (152, 0.930000000000000),
#  (156, 0.970000000000000),
#  (158, 0.980000000000000),
#  (162, 1.00000000000000),
#  (164, 1.00000000000000),
#  (166, 1.01000000000000),
#  (168, 1.01000000000000),
#  (170, 1.00000000000000),
#  (172, 1.00000000000000),
#  (174, 0.990000000000000),
#  (176, 0.980000000000000),
#  (178, 0.970000000000000),
#  (180, 0.960000000000000),
#  (182, 0.940000000000000),
#  (184, 0.920000000000000),
#  (186, 0.900000000000000),
#  (188, 0.880000000000000),
#  (190, 0.860000000000000),
#  (200, 0.720000000000000),
#  (210, 0.560000000000000),
#  (220, 0.380000000000000),
#  (230, 0.210000000000000),
#  (240, 0.0900000000000000),
#  (250, 0.0200000000000000),
#  (260, 0)]

# %%
point(Parells2) + plot(cos((x*pi/180))^2, xmin = 90, xmax = 270, color = 'red' )
# Out:
# Graphics object consisting of 2 graphics primitives
